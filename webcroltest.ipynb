# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time

# 크롬 드라이버를 실행하여 크롬 브라우저를 자동화하여 데이터 수집
url = 'https://anime.onnada.com/rank.php'
path = "C:\py_temp\chromedriver_win32\chromedriver.exe" # 컴퓨터 환경에 따라 변경해야함?
driver = webdriver.Chrome(path)
driver.get(url)
time.sleep(5)

html = driver.page_source
print(html)

driver.quit()

#soup = BeautifulSoup(response.text, 'html.parser')
#print(soup)

# ol = soup.select_one('.layout-line')
# ol
#li_list = ol.find_all('li')
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml"><head>
#     <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" />
#     <meta charset="utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge,IE=9,chrome=1" />
# <meta name="name" content="애니메이션 순위" />
# <title>애니메이션 순위</title>
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="theme-color" content="#ff6f99" />
# <meta property="fb:app_id" content="741684519281712" />
# <meta property="og:url" content="https://anime.onnada.com/rank.php" />
# <meta property="og:type" content="website" />
# <meta property="og:title" content="애니메이션 순위" />
# <meta property="og:subject" content="" />
# <meta property="og:description" content="" />
# <meta property="og:image" content="" />
# <meta property="og:image:width" content="" />
# <meta property="og:image:height" content="" />
# <meta property="og:locale" content="ko_KR" />
# <meta property="og:site_name" content="온나다" />
# <link rel="shortcut icon" href="//member.onnada.com/_/img/f16x16.ico" />
# <link rel="apple-touch-icon" sizes="114x114" href="//member.onnada.com/_/img/f114x114.png" />
# <link rel="stylesheet" href="//member.onnada.com/_/css/web.css?v=13" type="text/css" />
# <link rel="stylesheet" href="//member.onnada.com/_/css/blueimp-gallery.min.css?v=13" />
# <script src="https://partner.googleadservices.com/gampad/cookie.js?domain=anime.onnada.com&amp;callback=_gfp_s_&amp;client=ca-pub-8122469435379428"></script><script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202306080101/show_ads_impl_fy2021.js" id="google_shimpl"></script><script type="text/javascript">var web_url = '/';var web_kakaomsg = '온나다 https://web.onnada.com';var web_tel = '';var web_sms = '';var bbs_id = '';var bbs_url = 'https://bbs2.onnada.com';var rbbs_url = 'https://w6.onnada.com/bbs';var article_id = '';var check_login = '';var check_admin = '';var check_bbsadmin = '';var check_touch = '';var check_browser= 'Chrome';var form_check = '14d58a1ba286f087d973';document.domain = 'onnada.com';</script>
# <script type="text/javascript" src="//member.onnada.com/_/js/jquery-1.12.4.min.js"></script>
# <script type="text/javascript" src="//member.onnada.com/_/js/jquery-ui.min.js"></script>
# <script type="text/javascript" src="//member.onnada.com/_/js/jquery.cookie.js"></script>
# <script type="text/javascript" src="//member.onnada.com/_/js/jquery.selectBox.min.js"></script>
# <script type="text/javascript" src="//member.onnada.com/_/js/jquery.blueimp-gallery.min.js?v=13"></script>
# <script type="text/javascript" src="//member.onnada.com/_/js/jquery.lazyload.js?v=13"></script>
# <script type="text/javascript" src="//member.onnada.com/_/js/web.js?v=13"></script>
# <!--[if lt IE 9]>
# <script type="text/javascript" src="//member.onnada.com/_/js/html5shiv.js"></script>
# <script type="text/javascript" src="//member.onnada.com/_/js/respond.min.js"></script>
# <![endif]-->
# <!--[if (gte IE 6)&(lte IE 8)]>
# <script type="text/javascript" src="//member.onnada.com/_/js/selectivizr-min.js"></script>
# <![endif]-->
# <style type="text/css">
# .layout-line {border:1px solid #e8e8e8; box-shadow:0px 1px 2px #e5e5e5; background-color:#ffffff; padding:15px 15px 15px 15px;}
#
# .select-wrap {text-align:center;}
#
# .web-array {margin-top:15px;}
# .web-array .thumb img {max-width:100px;}
#
# .web-array .rank {width:60px;}
# .web-array .thumb {width:120px;}
# .web-array .category {width:180px;}
# .web-array .date {width:100px;}
# .web-array .move {width:100px;}
# .web-array tr.array td, .list-array tr.array td a {line-height:18px;}
#
# @media screen and (max-width:800px) {
#
# .web-array .date {display:none;}
#
# }
#
# @media screen and (max-width:640px) {
#
# .layout-line {border:0; box-shadow:none; padding:15px 0 0 0;}
#
# .web-array .category {display:none;}
# .web-array .rank {width:50px;}
# .web-array .thumb {width:90px;}
# .web-array .thumb a img {max-width:80px;}
# .web-array .move {width:60px;}
#
# }
# </style>
# <script type="text/javascript">
# function fSort()
# {
#
#     var f = document.formSort;
#
#     f.submit();
#
# }
# </script>
#     <link rel="stylesheet" href="//member.onnada.com/_/css/template.css?v=13" type="text/css" />
#     <style type="text/css">
#             </style>
#     <script type="text/javascript">
#         var web_host = "anime";
#         var web_menu = "rank";
#         var web_menusub = "rank";
#     </script>
#     <script type="text/javascript" src="//member.onnada.com/_/js/template.js?v=13"></script>
#     <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8122469435379428" crossorigin="anonymous" data-checked-head="true"></script>
# <meta http-equiv="origin-trial" content="" /><meta http-equiv="origin-trial" content="" /><meta http-equiv="origin-trial" content="" /><meta http-equiv="origin-trial" content="" /><meta http-equiv="origin-trial" content="" /><link rel="preload" href="https://adservice.google.com/adsid/integrator.js?domain=anime.onnada.com" as="script" /><script type="text/javascript" src="https://adservice.google.com/adsid/integrator.js?domain=anime.onnada.com"></script></head>
# <body>
# <div id="update"></div><div id="update_data"></div><div id="overlay"></div><div id="messagebox"></div><div id="socialbox"></div><div id="sideviewbox"></div><div id="imagebox"></div>
# <div id="blueimp-gallery" class="blueimp-gallery blueimp-gallery-controls"><div class="slides"></div><h3 class="title"></h3><a class="prev">‹</a><a class="next">›</a><a class="close">×</a><a class="play-pause"></a></div>
# <form name="formUpdate" method="post" autocomplete="off"><input type="hidden" name="form_check" value="14d58a1ba286f087d973" /><input type="hidden" name="url" value="https%3A%2F%2Fanime.onnada.com%2Frank.php" /><input type="hidden" name="m" value="" /><input type="hidden" name="bbs_id" value="" /><input type="hidden" name="bbs_group" value="" /><input type="hidden" name="page_group" value="" /><input type="hidden" name="page_id" value="" /><input type="hidden" name="popup_id" value="" /><input type="hidden" name="article_id" value="" /><input type="hidden" name="reply_id" value="" /><input type="hidden" name="blind" value="" /><input type="hidden" name="file_id" value="" /><input type="hidden" name="id" value="" /><input type="hidden" name="mid" value="" /><input type="hidden" name="p" value="" /><input type="hidden" name="nav" value="" /><input type="hidden" name="book_read" value="" /><input type="hidden" name="comic_read" value="" /><input type="hidden" name="sort" value="" /><input type="hidden" name="rows" value="" /><input type="hidden" name="table" value="" /><input type="hidden" name="return" value="" /><input type="hidden" name="popup" value="" /></form><header>
#     <nav>
#         <!-- layout-top start //-->
#         <div class="layout-top">
#             <div class="layout-nav">
#                 <ul>
#                     <li><a href="https://web.onnada.com/">홈으로</a></li>
#                     <li><a href="https://bbs2.onnada.com/bookmark.php">북마크</a></li>
#                     <li><a href="https://bbs2.onnada.com/best.php">인기글</a></li>
#                     <li><a href="https://bbs2.onnada.com/">최신글</a></li>
#                     <li><a href="https://bbs2.onnada.com/reply_new.php">댓글</a></li>
#                     <div class="side">
#                                                     <li><a href="https://member.onnada.com/login/?url=https%3A%2F%2Fanime.onnada.com%2Frank.php">로그인</a></li>
#                             <li><a href="https://member.onnada.com/join/">회원가입</a></li>
#                                                 <li><a href="https://web.onnada.com/member/connect/">접속자<span id="nav_connect_count"></span></a></li>
#                         <li><a href="https://web.onnada.com/other/check/">출석부</a></li>
#                         <li><a href="https://web.onnada.com/member/rank/">랭킹</a></li>
#                         <li><a href="https://web.onnada.com/member/rank/search.php">회원</a></li>
#                     </div>
#                 </ul>
#             </div>
#             <div class="topmenu">
#                 <div class="logo"><a href="https://web.onnada.com/"><img src="//member.onnada.com/_/img/logo239x40.png" /></a></div>
#                 <div class="search">
#                     <form method="get" name="formNavSearch" action="https://web.onnada.com/search/">
#                         <ul>
#                             <li class="input"><input type="text" name="q" value="" /></li>
#                             <li class="submit"><input type="image" src="//member.onnada.com/_/img/blank.png" /></li>
#                         </ul>
#                     </form>
#                 </div>
#             </div>
#             <!-- submenu start //-->
#             <div class="submenu" style="position: absolute; top: 112px;">
#                 <div class="wrap">
#                     <ul>
#                         <li data-host="talk">
#                             <a href="https://bbs2.onnada.com/E000002" class="title">게시판</a>
#                             <div>
#                                 <a data-menu="B-E000002" href="https://bbs2.onnada.com/E000002">온나다 토크</a>
#                                 <a data-menu="B-moe" href="https://bbs2.onnada.com/moe">모에모에</a>
#                                 <a data-menu="B-moemoe" href="https://bbs2.onnada.com/moemoe">모에모에 R15+</a>
#                                 <a data-menu="B-newgame" href="https://bbs2.onnada.com/newgame">내가 하는 게임</a>
#                             </div>
#                         </li>
#                         <li data-host="game">
#                             <a href="https://bbs2.onnada.com/game" class="title">게임</a>
#                             <div>
#                                 <a data-menu="B-game" href="https://bbs2.onnada.com/game">게임게시판</a>
#                                 <a data-menu="B-priconne" href="https://bbs2.onnada.com/priconne">프린세스 커넥트</a>
#                             </div>
#                         </li>
#                         <li data-host="news">
#                             <a href="https://bbs2.onnada.com/E000023" class="title">소식</a>
#                             <div>
#                                 <a data-menu="B-E000023" href="https://bbs2.onnada.com/E000023">새 소식</a>
#                                 <a data-menu="B-figure" href="https://bbs2.onnada.com/figure">피규어</a>
#                                 <a data-menu="B-E000007" href="https://bbs2.onnada.com/E000007">애니움짤</a>
#                                 <a data-menu="B-E000024" href="https://bbs2.onnada.com/E000024">풀캡처</a>
#                                 <a data-menu="B-E000039" href="https://bbs2.onnada.com/E000039">아이캐치</a>
#                                 <a data-menu="B-E000031" href="https://bbs2.onnada.com/E000031">엔드카드</a>
#                                 <a data-menu="B-E000013" href="https://bbs2.onnada.com/E000013">옥에티</a>
#                             </div>
#                         </li>
#                         <li data-host="anime" class="on">
#                             <a href="https://anime.onnada.com/rank.php" class="title">애니</a>
#                             <div>
#                                 <a data-menu="rank" href="https://anime.onnada.com/rank.php" class="on">애니 순위</a>
#                                 <a data-menu="quarter" href="https://anime.onnada.com/quarter.php">분기별</a>
#                                 <a data-menu="onair" href="https://anime.onnada.com/onair.php">방영중</a>
#                                 <a data-menu="good" href="https://anime.onnada.com/good.php">추천순</a>
#                                 <a data-menu="hit" href="https://anime.onnada.com/hit.php">조회순</a>
#                                 <a data-menu="search" href="https://anime.onnada.com/search.php">최신순</a>
#                                 <a data-menu="wait" href="https://anime.onnada.com/wait.php">미방영</a>
#                                 <a data-menu="decide" href="https://anime.onnada.com/decide.php">제작 결정</a>
#                             </div>
#                         </li>
#                         <li data-host="character">
#                             <a href="https://character.onnada.com/rank.php" class="title">캐릭터</a>
#                             <div>
#                                 <a data-menu="rank" href="https://character.onnada.com/rank.php">캐릭터 순위</a>
#                                 <a data-menu="search" href="https://character.onnada.com/search.php">캐릭터 검색</a>
#                                 <a data-menu="birthday" href="https://character.onnada.com/birthday.php">캐릭터 생일</a>
#                                 <a data-menu="famous" href="https://character.onnada.com/famous.php">명대사</a>
#                             </div>
#                         </li>
#                         <li data-host="staff">
#                             <a href="https://staff.onnada.com/cv_rank.php" class="title">스태프</a>
#                             <div>
#                                 <a data-menu="cv_rank" href="https://staff.onnada.com/cv_rank.php">CV 순위</a>
#                                 <a data-menu="cv_character" href="https://staff.onnada.com/cv_character.php">CV 참여작품 순위</a>
#                                 <a data-menu="cv_search" href="https://staff.onnada.com/cv_search.php">CV 검색</a>
#                                 <a data-menu="staff_search" href="https://staff.onnada.com/staff_search.php">STAFF 검색</a>
#                             </div>
#                         </li>
#                         <li data-host="book">
#                             <a href="https://book.onnada.com/book.php" class="title">도서</a>
#                             <div>
#                                 <a data-menu="book" href="https://book.onnada.com/book.php">라이트노벨</a>
#                                 <a data-menu="comic" href="https://book.onnada.com/comic.php">만화코믹</a>
#                                 <a data-menu="art" href="https://book.onnada.com/art.php">화집</a>
#                                 <a data-menu="onair" href="https://book.onnada.com/onair.php">방영도서</a>
#                                 <a data-menu="offair" href="https://book.onnada.com/offair.php">종영도서</a>
#                                 <a data-menu="novel" href="https://book.onnada.com/novel">추천소설</a>
#                             </div>
#                         </li>
#                     </ul>
#                 </div>
#             </div>
#             <!-- submenu end //-->
#             <!-- mobile-top start //-->
#             <div class="mobile-top">
#                 <div class="btn_side"></div>
#                 <a href="https://web.onnada.com/"></a>
#             </div>
#             <!-- mobile-top end //-->
#         </div>
#         <!-- layout-top end //-->
#         <!-- layout-mobile start //-->
#         <div class="layout-mobile-close"></div>
#         <div class="layout-mobile">
#             <div class="login">
#                                     <a href="https://member.onnada.com/login/?url=https%3A%2F%2Fanime.onnada.com%2Frank.php"><span></span>로그인</a>
#                             </div>
#                             <div class="social">
#                     <ul>
#                                                     <li data-login="naver" class="naver" title="네이버"></li>
#                                                                             <li data-login="kakao" class="kakao" title="카카오톡"></li>
#                                                                             <li data-login="facebook" class="facebook" title="페이스북"></li>
#                                                                             <li data-login="twitter" class="twitter" title="트위터"></li>
#                                                                             <li data-login="google" class="google" title="구글"></li>
#                                                                     </ul>
#                 </div>
#                         <div class="menu">
#                     <ul>
#                         <li data-host="talk">
#                             <a href="https://bbs2.onnada.com/E000002" class="title">게시판</a>
#                             <div>
#                                 <a data-menu="B-E000002" href="https://bbs2.onnada.com/E000002">온나다 토크</a>
#                                 <a data-menu="B-moe" href="https://bbs2.onnada.com/moe">모에모에</a>
#                                 <a data-menu="B-moemoe" href="https://bbs2.onnada.com/moemoe">모에모에 R15+</a>
#                                 <a data-menu="B-newgame" href="https://bbs2.onnada.com/newgame">내가 하는 게임</a>
#                             </div>
#                         </li>
#                         <li data-host="game">
#                             <a href="https://bbs2.onnada.com/game" class="title">게임</a>
#                             <div>
#                                 <a data-menu="B-game" href="https://bbs2.onnada.com/game">게임게시판</a>
#                                 <a data-menu="B-priconne" href="https://bbs2.onnada.com/priconne">프린세스 커넥트</a>
#                             </div>
#                         </li>
#                         <li data-host="news">
#                             <a href="https://bbs2.onnada.com/E000023" class="title">소식</a>
#                             <div>
#                                 <a data-menu="B-E000023" href="https://bbs2.onnada.com/E000023">새 소식</a>
#                                 <a data-menu="B-figure" href="https://bbs2.onnada.com/figure">피규어</a>
#                                 <a data-menu="B-E000007" href="https://bbs2.onnada.com/E000007">애니움짤</a>
#                                 <a data-menu="B-E000024" href="https://bbs2.onnada.com/E000024">풀캡처</a>
#                                 <a data-menu="B-E000039" href="https://bbs2.onnada.com/E000039">아이캐치</a>
#                                 <a data-menu="B-E000031" href="https://bbs2.onnada.com/E000031">엔드카드</a>
#                                 <a data-menu="B-E000013" href="https://bbs2.onnada.com/E000013">옥에티</a>
#                             </div>
#                         </li>
#                         <li data-host="anime" class="">
#                             <a href="https://anime.onnada.com/rank.php" class="title">애니</a>
#                             <div>
#                                 <a data-menu="rank" href="https://anime.onnada.com/rank.php" class="on">애니 순위</a>
#                                 <a data-menu="quarter" href="https://anime.onnada.com/quarter.php">분기별</a>
#                                 <a data-menu="onair" href="https://anime.onnada.com/onair.php">방영중</a>
#                                 <a data-menu="good" href="https://anime.onnada.com/good.php">추천순</a>
#                                 <a data-menu="hit" href="https://anime.onnada.com/hit.php">조회순</a>
#                                 <a data-menu="search" href="https://anime.onnada.com/search.php">최신순</a>
#                                 <a data-menu="wait" href="https://anime.onnada.com/wait.php">미방영</a>
#                                 <a data-menu="decide" href="https://anime.onnada.com/decide.php">제작 결정</a>
#                             </div>
#                         </li>
#                         <li data-host="character">
#                             <a href="https://character.onnada.com/rank.php" class="title">캐릭터</a>
#                             <div>
#                                 <a data-menu="rank" href="https://character.onnada.com/rank.php">캐릭터 순위</a>
#                                 <a data-menu="search" href="https://character.onnada.com/search.php">캐릭터 검색</a>
#                                 <a data-menu="birthday" href="https://character.onnada.com/birthday.php">캐릭터 생일</a>
#                                 <a data-menu="famous" href="https://character.onnada.com/famous.php">명대사</a>
#                             </div>
#                         </li>
#                         <li data-host="staff">
#                             <a href="https://staff.onnada.com/cv_rank.php" class="title">스태프</a>
#                             <div>
#                                 <a data-menu="cv_rank" href="https://staff.onnada.com/cv_rank.php">CV 순위</a>
#                                 <a data-menu="cv_character" href="https://staff.onnada.com/cv_character.php">CV 참여작품 순위</a>
#                                 <a data-menu="cv_search" href="https://staff.onnada.com/cv_search.php">CV 검색</a>
#                                 <a data-menu="staff_search" href="https://staff.onnada.com/staff_search.php">STAFF 검색</a>
#                             </div>
#                         </li>
#                         <li data-host="book">
#                             <a href="https://book.onnada.com/book.php" class="title">도서</a>
#                             <div>
#                                 <a data-menu="book" href="https://book.onnada.com/book.php">라이트노벨</a>
#                                 <a data-menu="comic" href="https://book.onnada.com/comic.php">만화코믹</a>
#                                 <a data-menu="art" href="https://book.onnada.com/art.php">화집</a>
#                                 <a data-menu="onair" href="https://book.onnada.com/onair.php">방영도서</a>
#                                 <a data-menu="offair" href="https://book.onnada.com/offair.php">종영도서</a>
#                                 <a data-menu="novel" href="https://book.onnada.com/novel">추천소설</a>
#                             </div>
#                         </li>
#                     </ul>
#                 </div>
#             <div class="menubottom">
#                 <a href="https://bbs2.onnada.com/best.php">인기 게시물</a>
#                 <a href="https://bbs2.onnada.com/">최신 게시물</a>
#                 <a href="https://bbs2.onnada.com/reply_new.php">최신 댓글</a>
#                 <a href="https://bbs2.onnada.com/bookmark.php">북마크</a>
#                 <a href="https://web.onnada.com/member/connect/">접속자</a>
#                 <a href="https://web.onnada.com/other/check/">출석부</a>
#                 <a href="https://web.onnada.com/member/rank/">랭킹</a>
#                 <a href="https://web.onnada.com/member/rank/search.php">회원</a>
#                 <a href="http://onnada.com/page/service">서비스 이용약관</a>
#                 <a href="http://onnada.com/page/privacy">개인정보 처리방침</a>
#                 <a href="https://bbs2.onnada.com/notice">공지사항</a>
#             </div>
#             <div class="copyright">Copyright © <b>온나다</b> Corp.</div>
#         </div>
#         <!-- layout-mobile end //-->
#     </nav>
# </header>
# <div class="layout-wrap">
#     <div class="layout-contents">
#         <div class="layout-main"><div class="layout-line">
# <form method="get" name="formSort" class="select-wrap">
# <div class="select-block">
# <!-- selectbox //-->
# <div class="selectbox">
# <div class="select" rel="fSort">
# <div class="block">
# <span class="text">2023년</span>
# <div class="option"><input type="hidden" name="yy" value="2023" class="add" />
# <ul class="array">
# <li data-value="2023" class="on">2023년</li><li data-value="2022">2022년</li><li data-value="2021">2021년</li><li data-value="2020">2020년</li><li data-value="2019">2019년</li><li data-value="2018">2018년</li></ul>
# </div>
# </div>
# </div>
# </div>
# <!-- selectbox //-->
# <!-- selectbox //-->
# <div class="selectbox">
# <div class="select" rel="fSort">
# <div class="block">
# <span class="text">06월</span>
# <div class="option"><input type="hidden" name="mm" value="06" class="add" />
# <ul class="array">
# <li data-value="01">01월</li><li data-value="02">02월</li><li data-value="03">03월</li><li data-value="04">04월</li><li data-value="05">05월</li><li data-value="06" class="on">06월</li><li data-value="07">07월</li><li data-value="08">08월</li><li data-value="09">09월</li><li data-value="10">10월</li><li data-value="11">11월</li><li data-value="12">12월</li></ul>
# </div>
# </div>
# </div>
# </div>
# <!-- selectbox //-->
# <!-- selectbox //-->
# <div class="selectbox">
# <div class="select" rel="fSort">
# <div class="block">
# <span class="text">19일</span>
# <div class="option"><input type="hidden" name="dd" value="19" class="add" />
# <ul class="array">
# <li data-value="01">01일</li><li data-value="02">02일</li><li data-value="03">03일</li><li data-value="04">04일</li><li data-value="05">05일</li><li data-value="06">06일</li><li data-value="07">07일</li><li data-value="08">08일</li><li data-value="09">09일</li><li data-value="10">10일</li><li data-value="11">11일</li><li data-value="12">12일</li><li data-value="13">13일</li><li data-value="14">14일</li><li data-value="15">15일</li><li data-value="16">16일</li><li data-value="17">17일</li><li data-value="18">18일</li><li data-value="19" class="on">19일</li><li data-value="20">20일</li><li data-value="21">21일</li><li data-value="22">22일</li><li data-value="23">23일</li><li data-value="24">24일</li><li data-value="25">25일</li><li data-value="26">26일</li><li data-value="27">27일</li><li data-value="28">28일</li><li data-value="29">29일</li><li data-value="30">30일</li><li data-value="31">31일</li></ul>
# </div>
# </div>
# </div>
# </div>
# <!-- selectbox //-->
# </div>
# </form>
# <table width="100%" cellpadding="0" cellspacing="0" border="0" class="web-array">
# <tbody><tr><td colspan="6" height="1" bgcolor="#e8e8e8"></td></tr>
# <tr class="subj">
#     <td class="rank">순위</td>
#     <td class="thumb">이미지</td>
#     <td class="maintitle">애니메이션</td>
#     <td class="category">장르</td>
#     <td class="date">방영일</td>
#     <td class="move">변동</td>
# </tr>
# <tr><td colspan="6" height="1" bgcolor="#e8e8e8"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">1 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4881/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_00c8d491_.25.05.JPG" align="absmiddle" border="0" alt="" src="https://data.onnada.com/anime/202303/thumb300x400_2937857715_00c8d491_.25.05.JPG" style="display: inline;" /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4881/nav/rank" target="_blank">최애의 아이</a></td>
#     <td class="category">아이돌</td>
#     <td class="date">2023.04.12</td>
#     <td class="move pointer" onclick="rankAnime('4881');"><img src="//member.onnada.com/_/img/real_stop.gif" width="5" height="2" class="up3" /> <span class="move">0</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">2 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5024/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202304/thumb300x400_1994052142_e65be0a0_sual02.jpg" align="absmiddle" border="0" alt="" src="https://data.onnada.com/anime/202304/thumb300x400_1994052142_e65be0a0_sual02.jpg" style="display: inline;" /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5024/nav/rank" target="_blank">이세계에서 치트 능력을 손에 넣은 나는, 현실세계에서도 무쌍한다 ~레벨 업은 인생을 바꿨다~</a></td>
#     <td class="category">이세계, 판타지, 하렘</td>
#     <td class="date">2023.04.04</td>
#     <td class="move pointer" onclick="rankAnime('5024');"><img src="//member.onnada.com/_/img/real_stop.gif" width="5" height="2" class="up3" /> <span class="move">0</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">3 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5000/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202302/thumb300x400_2937857715_875ffedb_AE_DNm.jpg" align="absmiddle" border="0" alt="" src="https://data.onnada.com/anime/202302/thumb300x400_2937857715_875ffedb_AE_DNm.jpg" style="display: inline;" /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5000/nav/rank" target="_blank">내 마음의 위험한 녀석</a></td>
#     <td class="category">개그, 학원, 로맨스, 코미</td>
#     <td class="date">2023.04.02</td>
#     <td class="move pointer" onclick="rankAnime('5000');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">2</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">4 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4621/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_b98c7286_AIClVE.jpg" align="absmiddle" border="0" alt="" src="https://data.onnada.com/anime/202303/thumb300x400_2937857715_b98c7286_AIClVE.jpg" style="display: inline;" /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4621/nav/rank" target="_blank">라이어・라이어</a></td>
#     <td class="category">학원, 로맨스, 코미디</td>
#     <td class="date">2023.07.08</td>
#     <td class="move pointer" onclick="rankAnime('4621');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">5 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5005/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202304/thumb300x400_3718766049_f1b54861_kv.jpg" align="absmiddle" border="0" alt="" src="https://data.onnada.com/anime/202304/thumb300x400_3718766049_f1b54861_kv.jpg" style="display: inline;" /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5005/nav/rank" target="_blank">전생귀족의 이세계 모험록 ~자중할 줄 모르는 신들의 사도~</a></td>
#     <td class="category">이세계, 판타지, 하렘</td>
#     <td class="date">2023.04.03</td>
#     <td class="move pointer" onclick="rankAnime('5005');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">6 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4791/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_7532252e_AEdV3p.jpg" align="absmiddle" border="0" alt="" src="https://data.onnada.com/anime/202303/thumb300x400_2937857715_7532252e_AEdV3p.jpg" style="display: inline;" /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4791/nav/rank" target="_blank">귀멸의 칼날: 도공 마을편</a></td>
#     <td class="category">시대, 판타지, 액션, 배틀</td>
#     <td class="date">2023.04.09</td>
#     <td class="move pointer" onclick="rankAnime('4791');"><img src="//member.onnada.com/_/img/real_stop.gif" width="5" height="2" class="up3" /> <span class="move">0</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">7 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5112/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_68778b9e_AE8w72.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5112/nav/rank" target="_blank">야마다 군과 Lv999의 사랑을 하다</a></td>
#     <td class="category">로맨스</td>
#     <td class="date">2023.04.02</td>
#     <td class="move pointer" onclick="rankAnime('5112');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">2</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">8 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4837/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202305/thumb300x400_2937857715_baf1f048_.13.39.JPG" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4837/nav/rank" target="_blank">무직전생 Ⅱ ~이세계에 갔으면 최선을 다한다~</a></td>
#     <td class="category">판타지, 이세계, 모험, 액</td>
#     <td class="date">2023.07.03</td>
#     <td class="move pointer" onclick="rankAnime('4837');"><img src="//member.onnada.com/_/img/real_stop.gif" width="5" height="2" class="up3" /> <span class="move">0</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">9 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4792/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_949f44d6_AULu7k.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4792/nav/rank" target="_blank">주술회전 (2023)</a></td>
#     <td class="category">능력, 배틀, 괴물, 마법</td>
#     <td class="date">2023.07.06</td>
#     <td class="move pointer" onclick="rankAnime('4792');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">7</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">10 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4578/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202212/thumb300x400_3718766049_efe1adf1_kv1.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4578/nav/rank" target="_blank">지옥락</a></td>
#     <td class="category">닌자, 판타지, 배틀</td>
#     <td class="date">2023.04.01</td>
#     <td class="move pointer" onclick="rankAnime('4578');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">4</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">11 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4723/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202302/thumb300x400_3718766049_485742ec_kv1.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4723/nav/rank" target="_blank">이세계 소환은 두 번째입니다</a></td>
#     <td class="category">이세계, 판타지, 일상, 하</td>
#     <td class="date">2023.04.09</td>
#     <td class="move pointer" onclick="rankAnime('4723');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">2</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">12 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5455/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202305/thumb300x400_991931501_c35bcbc2_137dbd.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5455/nav/rank" target="_blank">라이자의 아틀리에 ~어둠의 여왕과 비밀의 은신처~</a></td>
#     <td class="category">판타지</td>
#     <td class="date">2023.07.02</td>
#     <td class="move pointer" onclick="rankAnime('5455');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">13 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4742/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202306/thumb300x400_2937857715_ade3ea8e_AA5_-B.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4742/nav/rank" target="_blank">일곱 개의 마검이 지배한다</a></td>
#     <td class="category">판타지, 학원, 배틀</td>
#     <td class="date">2023.07.08</td>
#     <td class="move pointer" onclick="rankAnime('4742');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">6</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">14 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5072/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_3655ed7c_mv1.png" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5072/nav/rank" target="_blank">여신의 카페테라스</a></td>
#     <td class="category">로맨스, 코미디, 하렘, 카</td>
#     <td class="date">2023.04.08</td>
#     <td class="move pointer" onclick="rankAnime('5072');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">15 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4850/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202304/thumb300x400_1994052142_d33a973f_AARvsl.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4850/nav/rank" target="_blank">마사무네의 리벤지 R</a></td>
#     <td class="category">학원, 로맨스, 하렘, 코미</td>
#     <td class="date">2023.07.03</td>
#     <td class="move pointer" onclick="rankAnime('4850');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">5</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">16 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5252/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202306/thumb300x400_2937857715_f900b8e3_AA8Xyf.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5252/nav/rank" target="_blank">좋아하는 애가 안경을 깜빡했다</a></td>
#     <td class="category">로맨스, 코미디, 학원, 일</td>
#     <td class="date">2023.07.04</td>
#     <td class="move pointer" onclick="rankAnime('5252');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">4</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">17 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4861/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_1f428ffa_dou_kv.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4861/nav/rank" target="_blank">신 없는 세계의 신 활동</a></td>
#     <td class="category">판타지, 이세계</td>
#     <td class="date">2023.04.06</td>
#     <td class="move pointer" onclick="rankAnime('4861');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">18 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5070/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202306/thumb300x400_2937857715_8ffd9bda_AE7YQF.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5070/nav/rank" target="_blank">실은 나, 최강이었다?</a></td>
#     <td class="category">이세계, 판타지</td>
#     <td class="date">2023.07.02</td>
#     <td class="move pointer" onclick="rankAnime('5070');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">19 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4856/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202211/thumb300x400_1994052142_817e122d_AAZ91t.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4856/nav/rank" target="_blank">이세계는 스마트폰과 함께. 2</a></td>
#     <td class="category">판타지, 이세계, 먼치킨, </td>
#     <td class="date">2023.04.03</td>
#     <td class="move pointer" onclick="rankAnime('4856');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">4</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">20 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4878/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202205/thumb300x400_2887507969_42c84074_img.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4878/nav/rank" target="_blank">이 멋진 세계에 폭염을!</a></td>
#     <td class="category">판타지, 코미디</td>
#     <td class="date">2023.04.06</td>
#     <td class="move pointer" onclick="rankAnime('4878');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">6</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">21 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4834/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202210/thumb300x400_2937857715_30586a88_sual-a.png" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4834/nav/rank" target="_blank">이세계 원턴킬 누나 ~누나 동반 이세계 생활 시작했습니다~</a></td>
#     <td class="category">이세계, 판타지</td>
#     <td class="date">2023.04.07</td>
#     <td class="move pointer" onclick="rankAnime('4834');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">2</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">22 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5487/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202305/thumb300x400_1994052142_007c4776_AUlO4f.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5487/nav/rank" target="_blank">5등분의 신부 ∽</a></td>
#     <td class="category">일상, 로맨스, 코미디, 하</td>
#     <td class="date">2023.07.xx</td>
#     <td class="move pointer" onclick="rankAnime('5487');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">2</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">23 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4954/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_85cf95f9_AIadrM.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4954/nav/rank" target="_blank">마슐</a></td>
#     <td class="category">판타지, 코미디, 능력, 배</td>
#     <td class="date">2023.04.08</td>
#     <td class="move pointer" onclick="rankAnime('4954');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">4</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">24 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4602/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202209/thumb300x400_3718766049_0d76c60c_in_fix.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4602/nav/rank" target="_blank">마왕학원의 부적합자 Ⅱ ~사상 최강의 마왕인 시조, 전생해서 자손들의 학교에 다니다~</a></td>
#     <td class="category">판타지, 마왕, 먼치킨, 마</td>
#     <td class="date">2023.07.09</td>
#     <td class="move pointer" onclick="rankAnime('4602');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">25 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4790/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202302/thumb300x400_2937857715_a4995af0_AInE1C.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4790/nav/rank" target="_blank">헬크</a></td>
#     <td class="category">판타지</td>
#     <td class="date">2023.07.12</td>
#     <td class="move pointer" onclick="rankAnime('4790');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">4</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">26 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4706/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202305/thumb300x400_2937857715_00f51498_AAE27x.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4706/nav/rank" target="_blank">영웅교실</a></td>
#     <td class="category">학원, 배틀, 판타지, 하렘</td>
#     <td class="date">2023.07.09</td>
#     <td class="move pointer" onclick="rankAnime('4706');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">6</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">27 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5236/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202306/thumb300x400_2937857715_ae0305dc_AEmyiP.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5236/nav/rank" target="_blank">좀100 ~좀비가 되기 전에 하고 싶은 100가지~</a></td>
#     <td class="category">액션, 좀비, 서바이벌</td>
#     <td class="date">2023.07.09</td>
#     <td class="move pointer" onclick="rankAnime('5236');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">5</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">28 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5473/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202306/thumb300x400_2937857715_2b8a0d08_AAzJP6.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5473/nav/rank" target="_blank">호리미야 -piece-</a></td>
#     <td class="category">학원, 일상, 로맨스, 코미</td>
#     <td class="date">2023.07.01</td>
#     <td class="move pointer" onclick="rankAnime('5473');"><img src="//member.onnada.com/_/img/real_stop.gif" width="5" height="2" class="up3" /> <span class="move">0</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">29 위</td>
# ...
# <tr class="array" height="153">
#     <td class="rank">83 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5162/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202306/thumb300x400_2937857715_0126018a_AAeioF.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5162/nav/rank" target="_blank">AYAKA -아야카-</a></td>
#     <td class="category">판타지</td>
#     <td class="date">2023.07.02</td>
#     <td class="move pointer" onclick="rankAnime('5162');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">18</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">84 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4575/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202302/thumb300x400_2937857715_abc427eb_AEHczO.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4575/nav/rank" target="_blank">제물공주와 짐승의 왕</a></td>
#     <td class="category">판타지, 로맨스</td>
#     <td class="date">2023.04.20</td>
#     <td class="move pointer" onclick="rankAnime('4575');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">7</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">85 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5485/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_72e80886_mv4.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5485/nav/rank" target="_blank">문호 스트레이 독스 5기</a></td>
#     <td class="category">배틀, 능력, 미스테리, 드</td>
#     <td class="date">2023.07.12</td>
#     <td class="move pointer" onclick="rankAnime('5485');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">8</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">86 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5541/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202306/thumb300x400_2937857715_b8ffc40d_dan010.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5541/nav/rank" target="_blank">단다단</a></td>
#     <td class="category">퇴마, 배틀, 액션, SF,</td>
#     <td class="date">xxxx.xx.xx</td>
#     <td class="move pointer" onclick="rankAnime('5541');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">14</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">87 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4882/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202208/thumb300x400_3718766049_9f8fa0a8_vis-sp.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4882/nav/rank" target="_blank">용사 파티에서 추방된 비스트테이머, 최강종의 고양이귀 소녀와 만나다</a></td>
#     <td class="category">판타지, 하렘</td>
#     <td class="date">2022.10.01</td>
#     <td class="move pointer" onclick="rankAnime('4882');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">88 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4773/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202212/thumb300x400_3718766049_d33fda15_kv2.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4773/nav/rank" target="_blank">심부름꾼 사이토 씨, 이세계에 가다</a></td>
#     <td class="category">판타지, 이세계</td>
#     <td class="date">2023.01.08</td>
#     <td class="move pointer" onclick="rankAnime('4773');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">2</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">89 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4833/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202301/thumb300x400_3718766049_ec0df5a3_kv2.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4833/nav/rank" target="_blank">스파이 교실</a></td>
#     <td class="category">액션, 학원, 어드벤쳐</td>
#     <td class="date">2023.01.05</td>
#     <td class="move pointer" onclick="rankAnime('4833');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">15</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">90 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4848/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202208/thumb300x400_2937857715_38007c7b_OXwV5C.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4848/nav/rank" target="_blank">이세계 유유자적 농가</a></td>
#     <td class="category">이세계, 판타지, 하렘</td>
#     <td class="date">2023.01.06</td>
#     <td class="move pointer" onclick="rankAnime('4848');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">15</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">91 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4689/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202212/thumb300x400_2937857715_b577b861_AEKl4i.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4689/nav/rank" target="_blank">인간불신의 모험자들이 세상을 구하는 것 같습니다</a></td>
#     <td class="category">판타지</td>
#     <td class="date">2023.01.10</td>
#     <td class="move pointer" onclick="rankAnime('4689');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">2</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">92 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4955/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202302/thumb300x400_2937857715_76dafe89_AIrode.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4955/nav/rank" target="_blank">버디 윙 -골프 소녀들의 이야기- (2023)</a></td>
#     <td class="category">스포츠</td>
#     <td class="date">2023.04.08</td>
#     <td class="move pointer" onclick="rankAnime('4955');"><img src="//member.onnada.com/_/img/real_stop.gif" width="5" height="2" class="up3" /> <span class="move">0</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">93 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5469/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202305/thumb300x400_2937857715_dd4d3356_AM4oiM.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5469/nav/rank" target="_blank">슈가 애플 페어리 테일 (2023)</a></td>
#     <td class="category">판타지</td>
#     <td class="date">2023.07.07</td>
#     <td class="move pointer" onclick="rankAnime('5469');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">20</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">94 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4976/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202211/thumb300x400_2937857715_6c7843ba_mv.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4976/nav/rank" target="_blank">해고당한 암흑병사(30대)의 슬로우한 세컨드 라이프</a></td>
#     <td class="category">판타지</td>
#     <td class="date">2023.01.07</td>
#     <td class="move pointer" onclick="rankAnime('4976');"><img src="//member.onnada.com/_/img/real_stop.gif" width="5" height="2" class="up3" /> <span class="move">0</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">95 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5538/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202306/thumb300x400_2949468983_601fac74_hUkZ1w.png" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5538/nav/rank" target="_blank">데드셀</a></td>
#     <td class="category">모험</td>
#     <td class="date">2024.xx.xx</td>
#     <td class="move pointer" onclick="rankAnime('5538');"><img src="//member.onnada.com/_/img/real_down.gif" width="5" height="8" /> <span class="move">10</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">96 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4781/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202303/thumb300x400_2937857715_882b8a49_sual-1.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4781/nav/rank" target="_blank">앨리스 기어 아이기스 Expansion</a></td>
#     <td class="category">일상, 코미디</td>
#     <td class="date">2023.04.03</td>
#     <td class="move pointer" onclick="rankAnime('4781');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">97 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5210/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202302/thumb300x400_2937857715_4102032d_AEx7cV.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5210/nav/rank" target="_blank">월드 다이 스타</a></td>
#     <td class="category">음악, 드라마</td>
#     <td class="date">2023.04.09</td>
#     <td class="move pointer" onclick="rankAnime('5210');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">6</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">98 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/4753/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202210/thumb300x400_3718766049_4163917e_4x1024.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/4753/nav/rank" target="_blank">옆집 천사님 때문에 어느샌가 인간적으로 타락한 사연</a></td>
#     <td class="category">로맨스, 코미디</td>
#     <td class="date">2023.01.07</td>
#     <td class="move pointer" onclick="rankAnime('4753');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">1</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">99 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5102/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202302/thumb300x400_2937857715_276dee01_AAlAeK.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5102/nav/rank" target="_blank">도쿄 뮤우뮤우 뉴~♡ (2023)</a></td>
#     <td class="category">마법소녀, 능력, 전투, 드</td>
#     <td class="date">2023.04.05</td>
#     <td class="move pointer" onclick="rankAnime('5102');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">2</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# <tr class="array" height="153">
#     <td class="rank">100 위</td>
#     <td class="thumb"><a href="https://anime.onnada.com/5191/nav/rank" target="_blank"><img data-original="https://data.onnada.com/anime/202301/thumb300x400_2937857715_804b3e1a_AEDd3Z.jpg" align="absmiddle" border="0" alt="" src="..." /></a></td>
#     <td class="maintitle"><a href="https://anime.onnada.com/5191/nav/rank" target="_blank">외톨이 흡혈 공주의 고뇌</a></td>
#     <td class="category">판타지</td>
#     <td class="date">2023.10.xx</td>
#     <td class="move pointer" onclick="rankAnime('5191');"><img src="//member.onnada.com/_/img/real_up.gif" width="5" height="8" /> <span class="move">14</span></td>
# </tr>
# <tr><td bgcolor="#e8e8e8" colspan="6" height="1"></td></tr>
# </tbody></table>
# </div>
# </div>
# </div>
# </div>
# <footer>
#     <div class="layout-bottom">Copyright © ONNADA. All Rights Reserved.</div>
# </footer>
#
# <ins class="adsbygoogle adsbygoogle-noablate" data-adsbygoogle-status="done" style="display: none !important;" data-ad-status="unfilled"><div id="aswift_0_host" tabindex="0" title="Advertisement" aria-label="Advertisement" style="border: none; height: 0px; width: 0px; margin: 0px; padding: 0px; position: relative; visibility: visible; background-color: transparent; display: inline-block;"><iframe id="aswift_0" name="aswift_0" style="left:0;position:absolute;top:0;border:0;width:undefinedpx;height:undefinedpx;" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" frameborder="0" marginwidth="0" marginheight="0" vspace="0" hspace="0" allowtransparency="true" scrolling="no" src="https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-8122469435379428&amp;output=html&amp;adk=1812271804&amp;adf=3025194257&amp;lmt=1687193916&amp;plat=1%3A8%2C2%3A16777224%2C3%3A65536%2C4%3A65536%2C9%3A32776%2C16%3A8388608%2C17%3A32%2C24%3A32%2C25%3A32%2C30%3A1048576%2C32%3A32%2C41%3A32%2C42%3A32&amp;format=0x0&amp;url=https%3A%2F%2Fanime.onnada.com%2Frank.php&amp;ea=0&amp;pra=5&amp;wgl=1&amp;uach=WyJXaW5kb3dzIiwiMTAuMC4wIiwieDg2IiwiIiwiMTE0LjAuNTczNS4xMzQiLFtdLDAsbnVsbCwiNjQiLFtbIk5vdC5BL0JyYW5kIiwiOC4wLjAuMCJdLFsiQ2hyb21pdW0iLCIxMTQuMC41NzM1LjEzNCJdLFsiR29vZ2xlIENocm9tZSIsIjExNC4wLjU3MzUuMTM0Il1dLDBd&amp;dt=1687193915846&amp;bpp=2&amp;bdt=327&amp;idt=331&amp;shv=r20230614&amp;mjsv=m202306080101&amp;ptt=9&amp;saldr=aa&amp;abxe=1&amp;nras=1&amp;correlator=4841237439654&amp;frm=20&amp;pv=2&amp;ga_vid=1885006027.1687193916&amp;ga_sid=1687193916&amp;ga_hid=189954175&amp;ga_fc=0&amp;u_tz=540&amp;u_his=2&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1040&amp;u_aw=1920&amp;u_cd=24&amp;u_sd=1&amp;dmc=8&amp;adx=-12245933&amp;ady=-12245933&amp;biw=912&amp;bih=887&amp;scr_x=0&amp;scr_y=0&amp;eid=44759837%2C42532278%2C42532280%2C44759876%2C44759927%2C31071756%2C31075308%2C44788442%2C44794789&amp;oid=2&amp;pvsid=4370491020371244&amp;tmod=1268187521&amp;uas=0&amp;nvt=1&amp;fsapi=1&amp;fc=1920&amp;brdim=10%2C10%2C10%2C10%2C1920%2C0%2C945%2C1020%2C929%2C887&amp;vis=1&amp;rsz=%7C%7Cs%7C&amp;abl=NS&amp;fu=32768&amp;bc=31&amp;ifi=1&amp;uci=a!1&amp;fsb=1&amp;dtd=345" data-google-container-id="a!1" data-load-complete="true"></iframe></div></ins><iframe src="https://www.google.com/recaptcha/api2/aframe" width="0" height="0" style="display: none;"></iframe></body><iframe id="google_esf" name="google_esf" src="https://googleads.g.doubleclick.net/pagead/html/r20230614/r20190131/zrt_lookup.html" style="display: none;"></iframe></html>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
#from selenium.webdriver.support.select import Select
#from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time
import os
import urllib.request

#맛집 데이터 크롤링
print("=" *50)
print("    전국의 맛집 정보 추출하기 + 이미지 포함")
print("=" *50)

trial = ['','서울', '강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', '세종', '울산', '인천', '전남', '전북', '제주', '충남', '충북']

busan = ['', '강서구', '금정구', '기장군', '남구', '동구', '동래구', '부산진구', '북구', '사상구', '사하구', '서구', '수영구', '연제구', '영도구', '중구', '해운대구']
category = ['', '배달', '밥집', '카페', '술집', '고깃집', '횟집', '한식', '중식', '일식', '양식', '아시안', '멕시칸', '이탈리안', '프렌치', '뷔페', '브런치', '패스트푸드','분식', '국물요리', '면요리', '해산물']

#지역 입력
for idx in range(len(trial)):
    if idx % 6 == 0:
        print('\n')
    
    if idx == 0:
        print(f" {idx}. 전체", end='\t')
        continue

    print(f" {idx}. {trial[idx]}", end='\t')
print("\n")
trial_idx = int(input('위 지역 중 자료를 수집할 지역의 번호를 적어주세요~'))
print("\n")
print("=" * 50)

#시군구 입력 (부산일 경우만 입력 받을 거임)
busan_idx = 0
if trial_idx == 9: #부산
    for idx in range(len(busan)):
        if idx % 6 == 0:
            print('\n')
    
        if idx == 0:
            print(f" {idx}. 전체", end='\t')
            continue
        print(f" {idx}. {busan[idx]}", end='\t')
    print("\n")
    busan_idx = int(input('위 지역 중 자료를 수집할 지역의 번호를 적어주세요~'))
print("\n")
print("=" * 50)

#카테고리 입력
for idx in range(len(category)):
    if idx % 6 == 0:
        print('\n')
    
    if idx == 0:
        print(f" {idx}. 전체", end='\t')
        continue

    print(f" {idx}. {category[idx]}", end='\t')

print("\n")
category_idx = int(input('위 지역 중 자료를 수집할 지역의 번호를 적어주세요~'))
print("\n")
print("=" * 50)


# file_bool = int(input('결과를 엑셀 파일에 저장할까요?  1. Yes  2. No'))

# f_name = ''
# if file_bool == 1:
#     f_dir = input('결과 파일을 저장할 폴더명만 적어주세요! ')
#     now = time.localtime()
#     s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)
#     os.makedirs(f_dir + '_' +s + '_' + trial[trial_idx] + busan[busan_idx] + category[category_idx])
#     os.chdir(f_dir + '_' +s + '_' + trial[trial_idx] + busan[busan_idx] + category[category_idx])
#     f_name = trial[trial_idx] + busan[busan_idx] + '_' +category[category_idx] + '_' + s + 'csv'

# 크롬 브라우저 실행
path = "chromedriver.exe"
url = 'https://www.diningcode.com/list.dc?addr=' + trial[trial_idx] + '%20' + busan[busan_idx] +'&keyword=' + category[category_idx]
#driver = webdriver.Chrome(ChromeDriverManager().install())
driver = webdriver.Chrome()
driver.get(url)
time.sleep(4)

# 스크롤 다운
def scroll_down(driver, tag):
    #driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    driver.execute_script("arguments[0].scrollBy(0, arguments[0].scrollHeight);", tag)
    time.sleep(1)


list_selector = "#root > div > div"
ac = driver.find_element(By.CSS_SELECTOR, list_selector)
ti = driver.find_element(By.CLASS_NAME, 'Filter__Info__Title')
arrow = driver.find_element(By.ID, 'arrow')

more = driver.find_element(By.XPATH, '//*[@id="map"]/button[2]')
more.click()

while True:
    try:
        more = driver.find_element(By.XPATH, '//*[@id="map"]/button[2]')
        more.click()
    except Exception:
        break

time.sleep(3)
arrow.send_keys(Keys.END)

# driver.execute_script("arguments[0].scrollBy(0, document.body.scrollHeight);", ac)


#select_date = Select(driver.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div[3]/form/div/div[1]/div/select'))

html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')
restaurant_list = soup.select('#root > div > div > div > a')
# print(restaurant_list)

ranking = []
rest_category =[]
score = []
user_score = []

# 이미지 저장용 폴더생성
# img_dir = f_dir+"\\images"
# os.makedirs(img_dir)
# os.chdir(img_dir)

for li in restaurant_list:
    rank = li.select_one('.RHeader > .Info > .InfoHeader > h2')
    print(rank.get_text())


#yummy = pd.DataFrame()
#yummy['점수'] = pd.Series()
# Out:
# ==================================================
#     전국의 맛집 정보 추출하기 + 이미지 포함
# ==================================================
#
#
#  0. 전체	 1. 서울	 2. 강원	 3. 경기	 4. 경남	 5. 경북
#
#  6. 광주	 7. 대구	 8. 대전	 9. 부산	 10. 세종	 11. 울산
#
#  12. 인천	 13. 전남	 14. 전북	 15. 제주	 16. 충남	 17. 충북
#
# 위 지역 중 자료를 수집할 지역의 번호를 적어주세요~4
#
#
# ==================================================
#
#
# ==================================================
#
#
#  0. 전체	 1. 배달	 2. 밥집	 3. 카페	 4. 술집	 5. 고깃집
#
#  6. 횟집	 7. 한식	 8. 중식	 9. 일식	 10. 양식	 11. 아시안
#
#  12. 멕시칸	 13. 이탈리안	 14. 프렌치	 15. 뷔페	 16. 브런치	 17. 패스트푸드
#
#  18. 분식	 19. 국물요리	 20. 면요리	 21. 해산물
#
# 위 지역 중 자료를 수집할 지역의 번호를 적어주세요~3
#
#
# ==================================================
# 1. 해이담 커피 김해
# 2. 미스티크 통영
# 3. 밤톨 하동
# 4. 에버어뮤즈 거제
# 5. 마틴커피 거제
# 6. 로스팅웨어 진주
# 7. 거제도외포멸치 거제
# 8. 남해촌집 화소반 남해
# 9. 블랙업 한화점
# 10. 아덴 원동점
# 11. 온 더 선셋 거제
# 12. 바이사이드 통영
# 13. N436 거제
# 14. 트리폰즈 양산
# 15. 드스텔라 커피 통영
# 16. 은율당 김해
# 17. 내성적싸롱 호심 통영
# 18. 카페톨 남해
# 19. 카페 녹음 하동
# 20. 쌍계명차 화개장터
# 21. 마소마레 거제
# 22. 욕지도할매바리스타 욕지도
# 23. 더웨이브147 거제
# 24. 팥파이스 남해
# 25. 외도널서리 거제
# 26. 매암차 박물관 하동
# 27. 백록림 양산
# 28. 울라봉 cafe & pub 통영
# 29. 카페유자 남해
# 30. 풀카페 거제
# 31. 카페 페이퍼가든 양산
# 32. st71 통영
# 33. 리묘 거제
# 34. 포블럭 통영
# 35. 크란츠러 남해
# 36. 패널커피 통영
# 37. 심해 거제
# 38. 루미노소 통영
# 39. 고품격커피공장 통영북신점
# 40. 시방리 카페 매미성점 거제
# 41. 하삼동커피 죽림점
# 42. 해월당 양산
# 43. 보다나은 통영
# 44. CAFE R 통영
# 45. 오송웨이브 거제
# 46. 스트롤링 커피 양산
# 47. 클라우드힐 통영
# 48. 블랙업커피 양산
# 49. 동네커피 진주혁신점
# 50. 하삼동커피 통영여객터미널점
# 51. 카페상촌 진주
# 52. 컴포즈커피  김해삼계
# 53. 느티나무의사랑 양산
# 54. 매일커피 통영
# 55. 네르하21 통영
# 56. 쿤스트라운지 남해군
# 57. 동네커피 통영
# 58. 카페 도어스 경남고성
# 59. 이거디 진주
# 60. 상주장 커피 남해
# 61. 온포인트커피 진주
# 62. 더세하 김해장유
# 63. 서부커피로스터스 김해
# 64. 갤러리&카페 라안 사천
# 65. 릴리로즈 통영
# 66. 카페오븐 통영
# 67. 딥밀 장유
# 68. 이메진커피 창원
# 69. 카페녘 통영
# 70. 다정카페 통도사
# 71. 무타블랑 양산
# 72. 하우요 커피 창원
# 73. 카페 단 양산
# 74. 선셋 경남고성
# 75. 블루일베이커리카페 거제
# 76. 파우제앤숨 김해
# 77. 하쿠나마타타 통영
# 78. 앵강마켓 남해
# 79. 번버리 양산
# 80. 웨이브 거제
# 81. 알베로 김해
# 82. 더로드101 하동
# 83. 가마등 양산
# 84. 브릿지130 하동
# 85. 카페인더박스 진주
# 86. 에이트카페 통영
# 87. 아라 욕지도
# 88. 드베이지 사천
# 89. 보타미 창원
# 90. 엘리먼트브루 진주
# 91. 브레이크 로스터스 창원
# 92. 카페당산 양산
# 93. 카페프라도 거제
# 94. 포지티브즈 통영
# 95. 만날 카페 통영
# 96. 커피크리머 상남동
# 97. 스타벅스 김해삼계점
# 98. 공간이음 진주
# 99. 카페 그레 통영
# 100. 카페해바라기 양산
